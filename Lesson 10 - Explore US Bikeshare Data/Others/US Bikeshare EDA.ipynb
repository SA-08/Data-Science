# %%
import numpy as np
import pandas as pd

# %%
newyorkcity = pd.read_csv(r'NYC-CitiBike-2016.csv')

# %%
newyorkcity.head(10000)
# Out:
#       tripduration           starttime            stoptime  start station id  \
# 0              839   1/1/2016 00:09:55   1/1/2016 00:23:54               532
# 1              686   1/1/2016 00:21:17   1/1/2016 00:32:44              3143
# 2              315   1/1/2016 00:33:11   1/1/2016 00:38:26              3164
# 3              739   1/1/2016 00:40:51   1/1/2016 00:53:11               223
# 4             1253   1/1/2016 00:44:16   1/1/2016 01:05:09               484
# ...            ...                 ...                 ...               ...
# 9995           218  1/31/2016 13:41:54  1/31/2016 13:45:33               490
# 9996           838  1/31/2016 13:41:54  1/31/2016 13:55:52               375
# 9997          1559  1/31/2016 13:42:37  1/31/2016 14:08:37               250
# 9998           981  1/31/2016 13:42:42  1/31/2016 13:59:03              3147
# 9999           576  1/31/2016 13:43:39  1/31/2016 13:53:15               291
#
# ...

# %%
chicago = pd.read_csv(r'Chicago-Divvy-2016.csv')

# %%
chicago.head(2)
# Out:
#    trip_id        starttime         stoptime  bikeid  tripduration  \
# 0  9080545  3/31/2016 23:30  3/31/2016 23:46    2295           926
# 1  9080521  3/31/2016 22:59  3/31/2016 23:02    3439           198
#
#    from_station_id            from_station_name  to_station_id  \
# 0              156    Clark St & Wellington Ave            166
# 1              259  California Ave & Francis Pl            276
#
#                 to_station_name    usertype gender  birthyear
# 0  Ashland Ave & Wrightwood Ave  Subscriber   Male     1990.0
# 1    California Ave & North Ave  Subscriber   Male     1974.0

# %%
washington = pd.read_csv(r'Washington-CapitalBikeshare-2016.csv')

# %%
washington.head(2)
# Out:
#    Duration (ms)       Start date         End date  Start station number  \
# 0         427387  3/31/2016 22:57  3/31/2016 23:04                 31602
# 1         587551  3/31/2016 22:46  3/31/2016 22:56                 31105
#
#              Start station  End station number  \
# 0  Park Rd & Holmead Pl NW               31207
# 1     14th & Harvard St NW               31266
#
#                       End station Bike number Member Type
# 0  Georgia Ave and Fairmont St NW      W20842  Registered
# 1                  11th & M St NW      W21385  Registered

# %%
washington['Member Type'].unique()
# Out:
# array(['Registered', 'Casual'], dtype=object)

# %%
chicago['usertype'].unique()
# Out:
# array(['Subscriber', 'Customer'], dtype=object)

# %%
newyorkcity['usertype'].unique()
# Out:
# array(['Customer', 'Subscriber', nan], dtype=object)

# %%
bikeshare = pd.read_csv('BayArea_Y3_trip_data.csv')

# %%
bikeshare.head(10)
# Out:
#    Trip ID  Duration     Start Date                             Start Station  \
# 0   913481       459  9/1/2015 6:01  San Francisco Caltrain (Townsend at 4th)
# 1   913538       535  9/1/2015 7:08      Harry Bridges Plaza (Ferry Building)
# 2   913693       445  9/1/2015 8:06  San Francisco Caltrain (Townsend at 4th)
# 3   913697       330  9/1/2015 8:06                    Embarcadero at Sansome
# 4   913707       970  9/1/2015 8:08  San Francisco Caltrain (Townsend at 4th)
# 5   913748       252  9/1/2015 8:16                         Market at Sansome
# 6   913778       539  9/1/2015 8:24         Civic Center BART (7th at Market)
# 7   913838       577  9/1/2015 8:40                     Embarcadero at Bryant
# 8   914013       689  9/1/2015 9:13                       Golden Gate at Polk
# 9   914126       860  9/1/2015 9:48                           Townsend at 7th
#
#    Start Terminal        End Date  \
# 0              70   9/1/2015 6:09
# 1              50   9/1/2015 7:17
# ...
